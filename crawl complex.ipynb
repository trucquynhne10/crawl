# %%
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime

# %%
import bs4
import requests
from selenium import webdriver
import os
import re
import unicodedata

#creating a directory to save images
folder_name = 'images'
if not os.path.isdir(folder_name):
    os.makedirs(folder_name)

def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, f"{num}.jpg"), 'wb') as file:
            file.write(reponse.content)

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
search_URL = 'https://www.gso.gov.vn/dan-so/'

df = pd.DataFrame()
def generate_short_title(title):
    title = re.sub(r'\W+', '', title)
    short_title = title[:8]
    return unicodedata.normalize('NFKD', short_title).encode('ASCII', 'ignore').decode('utf-8')

# %%
# !pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (2024.8.30)

# %% [markdown]
# Web dan so

# %%
def choose_step(length, u):
    if(u==1):
        if(length>1):
            return 4
        else:
            return 1
    elif(u==2):
        if(length>1):
            return 2
        else:
            return 1
    elif(u==3):
        return 1

# %%
def select_value(select, start, step):
    selected_list = []
    end = start + step
    options = select.options[start:end]
    
    for i, option in enumerate(options, start=start):
        select.select_by_index(i)
        selected_list.append(option.text)
        
    return selected_list

# %%
#Không dùng đến
def change_col1():
    driver.switch_to.default_content()
    iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
    driver.switch_to.frame(iframe)
    container = driver.find_element(By.CLASS_NAME, "commandbar")
    select_changecol = container.find_element(By.TAG_NAME, "select")
    selected_changecol =  Select(select_changecol)
    selected_changecol.select_by_value("pivotManual")
    container_box = driver.find_element(By.CLASS_NAME, "commandbar_container")
    box_container = container_box.find_elements(By.CLASS_NAME, "commandbar_pivot_container")
    for box in box_container:
        title = box.find_element(By.CLASS_NAME, "commandbar_pivot_title")    
        select_opt = box.find_element(By.TAG_NAME, "select")
        select_opt = Select(select_opt)
        if title.text == "Cột":
            select_opt.deselect_all()
            select_opt.select_by_value("Năm")
        else:
            select_opt.deselect_all()
            select_opt.select_by_value("Chỉ tiêu")
            select_opt.select_by_value("Địa phương")

# %%
def numCol(driver):
    # iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
    # driver.switch_to.frame(iframe)
    col_elements = driver.find_elements(By.CLASS_NAME, "variableselector_valuesselect_variabletitle")
    col_texts = []
    for element in col_elements:
        text = element.text
        col_texts.append(text)
    return col_texts

# %%
def change_col(str, col):
    container = driver.find_element(By.CLASS_NAME, "commandbar_dropdown")
    select_changecol = container.find_element(By.TAG_NAME, "select")
    selected_changecol = Select(select_changecol)
    selected_changecol.select_by_value("pivotManual")
    
    container_box = driver.find_element(By.CLASS_NAME, "commandbar_container")
    box_container = container_box.find_elements(By.CLASS_NAME, "commandbar_pivot_container")
    
    min_length = min(len(ele) for ele in str)
    max_length = max(len(ele) for ele in str)
    
    column = None  # Initialize column variable
    
    for i, ele in enumerate(str):
        if min_length < len(ele) < max_length:
            column = col[i]
            break
    
    for box in box_container:
        title = box.find_element(By.CLASS_NAME, "commandbar_pivot_title")
        select_opt = box.find_element(By.TAG_NAME, "select")
        select_opt = Select(select_opt)
        
        if title.text == "Cột":
            options = select_opt.options
            if len(options) > 0:
                for opt in options:
                    if opt.text == column:
                        select_opt.select_by_visible_text(opt.text)
                moveLeftButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_MoveLeftButton']")
                moveLeftButton.click()
        
        if title.text == "Hàng":
            options = select_opt.options
            if len(options) > 0:
                for opt in options:
                    if opt.text != column:
                        select_opt.select_by_visible_text(opt.text)
                moveRightButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_MoveRightButton']")
                moveRightButton.click()
    
    continueButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_ContinueButton']")
    continueButton.click()

# %%
def change_col2(str, col):
    # driver.switch_to.default_content()
    # iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
    # driver.switch_to.frame(iframe)
    container = driver.find_element(By.CLASS_NAME, "commandbar_dropdown")
    select_changecol = container.find_element(By.TAG_NAME, "select")
    selected_changecol =  Select(select_changecol)
    selected_changecol.select_by_value("pivotManual")
    container_box = driver.find_element(By.CLASS_NAME, "commandbar_container")
    box_container = container_box.find_elements(By.CLASS_NAME, "commandbar_pivot_container")
    # select_col = container.container
    min_length = min(len(ele) for ele in str)
    max_length = max(len(ele) for ele in str)


    if(len(str[0])>min_length and len(str[0])<max_length):
        column = col[0]
    elif(len(str[1])>min_length and len(str[1])<max_length):
        column = col[1]
    elif(len(str[2])>min_length and len(str[2])<max_length):
        column = col[2]

      
    for box in box_container:
        title = box.find_element(By.CLASS_NAME, "commandbar_pivot_title")    
        select_opt = box.find_element(By.TAG_NAME, "select")
        select_opt = Select(select_opt)
        if(title.text=="Cột"):
            # select_opt.deselect_all()
            options = select_opt.options
            if(len(options)>0):
                for opt in options:
                    if(opt.text == column):
                        select_opt.select_by_visible_text(opt.text)
                moveLeftButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_MoveLeftButton']")    
                moveLeftButton.click()
        if(title.text=="Hàng"):
            options = select_opt.options
            if(len(options)>0):
                for opt in options:
                    if(opt.text != column):
                        select_opt.select_by_visible_text(opt.text)
                moveRightButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_MoveRightButton']")    
                moveRightButton.click()
    continueButton = box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_PluginControl_PluginControl_ContinueButton']")  
    continueButton.click()

# %%
def change_name(name, typeChart):
    driver.switch_to.default_content()
    iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
    driver.switch_to.frame(iframe)
    container = driver.find_element(By.CLASS_NAME, "commandbar_dropdown")
    select_dropdown = container.find_elements(By.TAG_NAME, "select")
    # print(select_dropdown[1])
    Select(select_dropdown[2]).select_by_value(typeChart)
    container_box = driver.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_cphSettings_lnkShowChartSettings']")
    container_box.click()
    input_name = container_box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_cphSettings_txtTitle']")
    input_name.clear()
    input_name.send_keys(name)
    direct_label = container_box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_cphSettings_rblLabelOrientation_1']")
    direct_label.click()
    apply = container_box.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_cphSettings_btnApply']")
    apply.click()

# %%
def download_chart():
    container = driver.find_element(By.CLASS_NAME, "commandbar_dropdown")
    
    select_down = driver.find_element(By.CLASS_NAME, "commandbar_saveas_dropdownlist")
    
    
    Select(select_down).select_by_visible_text("Excel (xlsx)")
    saveFile = driver.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_commandbarDownloadFileLink']")
    saveFile.click()

    Select(select_down).select_by_visible_text("Biểu đồ dạng tệp ảnh JPEG")
    saveImg = driver.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_CommandBar1_CommandBar1_commandbarDownloadFileLink']")
    saveImg.click()

# %%
def setting_value(link):
    driver.get(link)
    # print(link)
    iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
    driver.switch_to.frame(iframe)
    
    # Tìm phần tử trong iframe bằng class
    container = driver.find_elements(By.CLASS_NAME, "variableselector_valuesselect_box.ui-resizable")
    selected_values = []
    for ele in container:
        select_elements = ele.find_elements(By.TAG_NAME, "select")
        for select in select_elements:
            selected = Select(select)
            selected_values.append(selected)
    # col_elements = driver.find_elements(By.CLASS_NAME, "variableselector_valuesselect_variabletitle")
    # col_texts = []
    # for element in col_elements:
    #     text = element.text
    #     col_texts.append(text)
    # num = numCol(driver)
    return selected_values

# %%
#down_chart
                    # submit_button = driver.find_element(By.CLASS_NAME, "variableselector_continue_button")
                    # submit_button.click()
                    # change_col()
                    # element_locator = (By.ID, "ctl00_ContentPlaceHolderMain_VariableSelector1_VariableSelector1_VariableSelectorValueSelectRepeater_ctl01_VariableValueSelect_VariableValueSelect_ValuesSelectContainerPanel")  # Thay thế bằng bộ lựa chọn phần tử cụ thể của bạn
                    # back_until_element_appears(element_locator)
                    # setting_value_again()
                    # # select_elements[2].deselect_all()
                    ## Dùng vòng lặp lưu các selected

# %%
# #test thử hàm
# def select_value_contain_old(select_elements):
#     selectList = [[] for _ in range(len(select_elements))]
#     start, start1, start2 = 0, 0 ,0
#     step, step1, step2 = 1, 1 ,1

#     # for id in range(len(select_elements)):
#     id = 0
#     if(id==1):
#         id1,id2 = 0, 2
#         step = choose_step(len(select_elements[id].options))
#     elif(id==0):
#         id1,id2 = 1, 2
#         step = choose_step(len(select_elements[id].options))

#     elif(id==2):
#         id1,id2 = 0, 1
#         step = choose_step(len(select_elements[id].options))

#     end = len(select_elements[id].options)
#     end1 = len(select_elements[id1].options)
#     end2 = len(select_elements[id2].options)
#     start = 0
#     # while(start+step <= end):
#     i=0
#     select_value(select_elements[id], start, step)
#     start1=0
#     selectList[id].append([start, step])
#     temp = [start, step]
#     while(start1+step1 <= 2):
#         select_value(select_elements[id1], start1, step1)
#         start2 = 0
#         selectList[id1].append([start, step])
#         temp1 = [start1, step1]
#         while(start2 +step2 <= end2):
#             select_value(select_elements[id2], start2, step2)
#             selectList[id].append(temp)
#             selectList[id1].append(temp1)
#             selectList[id2].append([start2, step2])
#             i+=1
#             start2+=step2
#             select_elements[id2].deselect_all()
            
#         start1+=step1
#         select_elements[id1].deselect_all()
#     start+=step
#     select_elements[id].deselect_all()
#     return selectList

# %%
def select_value_contain(select_elements):
    selectList = [[] for _ in range(len(select_elements))]

    # print(select_elements)
    # for i in range(len(select_elements)):
    #     print(len(select_elements[i].options))

    for id in range(len(select_elements)):
        if id == 1:
            id1, id2 = 0, 2
        elif id == 0:
            id1, id2 = 1, 2
        else:  # id == 2
            id1, id2 = 0, 1
        print(id, id1, id2)
        # Dynamically choose step based on current select element
        step = choose_step(len(select_elements[id].options), 1)
        step1= choose_step(len(select_elements[id1].options), 2)
        step2= choose_step(len(select_elements[id1].options), 3)
        print('step', step)
        # Define the end points based on the length of the select options
        end = len(select_elements[id].options)
        end1 = len(select_elements[id1].options)
        end2 = len(select_elements[id2].options)

        start = 1
        start1, start2 = 0, 0
        
        while(start+step <= end):
            i=0
            # selectList[id1].append([start1, step1])
            temp1 = [start1, step1] 
            temp2 = [start2, step2] 
            print('temp:', temp1, temp2)
            select_value(select_elements[id], start, step)
            select_value(select_elements[id1], start1 + step1, step1)
            select_value(select_elements[id2], start2 + step2, step2)
            selectList[id].append([start, step])
            selectList[id1].append(temp1)
            selectList[id2].append(temp2)
            
            start2 = 0 if start2 == end2 - 1 else start2 + step2
            select_elements[id2].deselect_all()
            start1 = 0 if start1 == end1 - 1 else start1 + step2
            select_elements[id1].deselect_all()
            start+=1
            select_elements[id].deselect_all()
            print(step, end, start)
            i+=1

    return selectList

# %% [markdown]
# # Hàm đã check

# %%
# def select_value_contain(select_elements):
#     selectList = [[] for _ in range(len(select_elements))]
#     start, start1, start2 = 0, 0 ,0
#     step, step1, step2 = 1, 1 ,1

#     for id in range(len(select_elements)):
#         if(id==1):
#             id1,id2 = 0, 2
#             step = choose_step(len(select_elements[id].options))
#         elif(id==0):
#             id1,id2 = 1, 2
#             step = choose_step(len(select_elements[id].options))

#         elif(id==2):
#             id1,id2 = 0, 1
#             step = choose_step(len(select_elements[id].options))

#         end = 10 if len(select_elements[id].options) > 5 else len(select_elements[id].options)
#         end1 = 10 if len(select_elements[id1].options) > 5 else len(select_elements[id1].options)
#         end2 = 10 if len(select_elements[id2].options) > 5 else len(select_elements[id2].options)
#         start = 0
#         while(start+step <= end):
#             i=0
#             select_value(select_elements[id], start, step)
#             start1=0
#             # selectList[id].append([start, step])
#             temp = [start, step]
#             while(start1+step1 <= end1):
#                 select_value(select_elements[id1], start1, step1)
#                 start2 = 0
#                 # selectList[id1].append([start1, step1])
#                 temp1 = [start1, step1]
#                 while(start2 +step2 <= end2):
#                     select_value(select_elements[id2], start2, step2)
#                     selectList[id].append(temp)
#                     selectList[id1].append(temp1)
#                     selectList[id2].append([start2, step2])
#                     i+=1
#                     start2+=step2
#                     select_elements[id2].deselect_all()
                    
#                 start1+=step1
#                 select_elements[id1].deselect_all()
#             start+=step
#             select_elements[id].deselect_all()
#     return selectList

# %%
def chart_setting(nameChart):
    settingButton = driver.find_element(By.CLASS_NAME, "settings_panel")
    settingButton.click()
    settingContainer = driver.find_element(By.XPATH, "//*[@id='ctl00_ctl00_ContentPlaceHolderMain_cphSettings_pnlSettings']")
    titleChart = settingContainer.find_element(By.TAG_NAME, input)
    titleChart.clear()
    titleChart.send_keys(nameChart)

# %%
def choose_name(vis):
    # Ensure all elements in vis are strings
    vis = [', '.join(v) if isinstance(v, list) else str(v) for v in vis]
    max_length = max(len(ele) for ele in vis)
    if len(vis[0]) ==max_length:
        return f"Dân số {vis[1]} trung bình của các địa phương trong năm {vis[2]}"
    elif len(vis[1]) == max_length:
        return f"Dân số trung bình giới tính và thành thị nông thôn của {vis[0]} trong năm {vis[2]}"
    else:
        return f"Dân số trung bình {vis[1]} của {vis[0]} qua các năm"

# %%
def getDetailItems(links):
    df = pd.DataFrame()
    driver.get(links)
    #Scrolling all the way up
    driver.execute_script("window.scrollTo(0, 0);")
    
    page_html = driver.page_source
    pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
    containers = pageSoup.find('div', {'class':"tab-pane fade fusion-clearfix in active"} )
    li_tags = ['https://www.gso.gov.vn/px-web-2/?pxid=V0203-07&theme=D%C3%A2n%20s%E1%BB%91%20v%C3%A0%20lao%20%C4%91%E1%BB%99ng']
    if containers:
        # In ra nội dung của mỗi thẻ <li>
        for li in li_tags:
            driver.get(li)
            selected_values = setting_value(li)
            numOfCol = numCol(driver)
            print(numOfCol)
            listValueId = select_value_contain(selected_values)
            name = ""
            # print(listValueId)
            for i in range(len(listValueId[0])):
                selected_values = setting_value(li)
                visual = []
                for j in range(3):
                    if(listValueId[j][i]!=listValueId[j][i-1]):
                        selected_values[j].deselect_all()
                    # if(listValueId[j][i][0]-listValueId[j][i][1]>1):    
                    vis = select_value(selected_values[j], listValueId[j][i][0], listValueId[j][i][1])
                    visual.append(vis)
                print(visual)
                name = choose_name(visual)
                submit_button = driver.find_element(By.CLASS_NAME, "variableselector_continue_button")
                submit_button.click()
                driver.switch_to.default_content()
                iframe = driver.find_element(By.XPATH, "//*[@id='post-26058']/div/iframe")
                driver.switch_to.frame(iframe)
                change_col(visual, numOfCol)
                if(i%2==0):
                    typeChart = "chartViewColumn"
                    change_name(name, typeChart)
                elif(i%2==1):
                    typeChart = "chartViewLine"
                    change_name(name, typeChart)
                download_chart()
                print(name)

# %%
getDetailItems(search_URL)
# Out:
# ['Tỉnh, thành phố', 'Dân số trung bình', 'Năm']
# 0 1 2
# step 4
# temp: [0, 2] [0, 1]
# 4 71 2
# temp: [1, 2] [2, 1]
# 4 71 3
# temp: [2, 2] [4, 1]
# 4 71 4
# temp: [3, 2] [6, 1]
# 4 71 5
# temp: [4, 2] [8, 1]
# 4 71 6
# temp: [0, 2] [10, 1]
# 4 71 7
# temp: [1, 2] [12, 1]
# 4 71 8
# temp: [2, 2] [14, 1]
# 4 71 9
# temp: [3, 2] [16, 1]
# 4 71 10
# temp: [4, 2] [18, 1]
# 4 71 11
# temp: [0, 2] [20, 1]
# 4 71 12
# temp: [1, 2] [22, 1]
# 4 71 13
# temp: [2, 2] [24, 1]
# 4 71 14
# temp: [3, 2] [26, 1]
# 4 71 15
# temp: [4, 2] [28, 1]
# 4 71 16
# temp: [0, 2] [0, 1]
# 4 71 17
# temp: [1, 2] [2, 1]
# 4 71 18
# temp: [2, 2] [4, 1]
# 4 71 19
# temp: [3, 2] [6, 1]
# 4 71 20
# temp: [4, 2] [8, 1]
# 4 71 21
# temp: [0, 2] [10, 1]
# 4 71 22
# temp: [1, 2] [12, 1]
# 4 71 23
# temp: [2, 2] [14, 1]
# 4 71 24
# temp: [3, 2] [16, 1]
# 4 71 25
# temp: [4, 2] [18, 1]
# 4 71 26
# temp: [0, 2] [20, 1]
# 4 71 27
# temp: [1, 2] [22, 1]
# 4 71 28
# temp: [2, 2] [24, 1]
# 4 71 29
# temp: [3, 2] [26, 1]
# 4 71 30
# temp: [4, 2] [28, 1]
# 4 71 31
# temp: [0, 2] [0, 1]
# 4 71 32
# temp: [1, 2] [2, 1]
# 4 71 33
# temp: [2, 2] [4, 1]
# 4 71 34
# temp: [3, 2] [6, 1]
# 4 71 35
# temp: [4, 2] [8, 1]
# 4 71 36
# temp: [0, 2] [10, 1]
# 4 71 37
# temp: [1, 2] [12, 1]
# 4 71 38
# temp: [2, 2] [14, 1]
# 4 71 39
# temp: [3, 2] [16, 1]
# 4 71 40
# temp: [4, 2] [18, 1]
# 4 71 41
# temp: [0, 2] [20, 1]
# 4 71 42
# temp: [1, 2] [22, 1]
# 4 71 43
# temp: [2, 2] [24, 1]
# 4 71 44
# temp: [3, 2] [26, 1]
# 4 71 45
# temp: [4, 2] [28, 1]
# 4 71 46
# temp: [0, 2] [0, 1]
# 4 71 47
# temp: [1, 2] [2, 1]
# 4 71 48
# temp: [2, 2] [4, 1]
# 4 71 49
# temp: [3, 2] [6, 1]
# 4 71 50
# temp: [4, 2] [8, 1]
# 4 71 51
# temp: [0, 2] [10, 1]
# 4 71 52
# temp: [1, 2] [12, 1]
# 4 71 53
# temp: [2, 2] [14, 1]
# 4 71 54
# temp: [3, 2] [16, 1]
# 4 71 55
# temp: [4, 2] [18, 1]
# 4 71 56
# temp: [0, 2] [20, 1]
# 4 71 57
# temp: [1, 2] [22, 1]
# 4 71 58
# temp: [2, 2] [24, 1]
# 4 71 59
# temp: [3, 2] [26, 1]
# 4 71 60
# temp: [4, 2] [28, 1]
# 4 71 61
# temp: [0, 2] [0, 1]
# 4 71 62
# temp: [1, 2] [2, 1]
# 4 71 63
# temp: [2, 2] [4, 1]
# 4 71 64
# temp: [3, 2] [6, 1]
# 4 71 65
# temp: [4, 2] [8, 1]
# 4 71 66
# temp: [0, 2] [10, 1]
# 4 71 67
# temp: [1, 2] [12, 1]
# 4 71 68
# 1 0 2
# step 4
# temp: [0, 2] [0, 1]
# 4 5 2
# 2 0 1
# step 4
# temp: [0, 2] [0, 1]
# 4 29 2
# temp: [1, 2] [2, 1]
# 4 29 3
# temp: [2, 2] [4, 1]
# 4 29 4
# temp: [3, 2] [0, 1]
# 4 29 5
# temp: [4, 2] [2, 1]
# 4 29 6
# temp: [5, 2] [4, 1]
# 4 29 7
# temp: [6, 2] [0, 1]
# 4 29 8
# temp: [7, 2] [2, 1]
# 4 29 9
# temp: [8, 2] [4, 1]
# 4 29 10
# temp: [9, 2] [0, 1]
# 4 29 11
# temp: [10, 2] [2, 1]
# 4 29 12
# temp: [11, 2] [4, 1]
# 4 29 13
# temp: [12, 2] [0, 1]
# 4 29 14
# temp: [13, 2] [2, 1]
# 4 29 15
# temp: [14, 2] [4, 1]
# 4 29 16
# temp: [15, 2] [0, 1]
# 4 29 17
# temp: [16, 2] [2, 1]
# 4 29 18
# temp: [17, 2] [4, 1]
# 4 29 19
# temp: [18, 2] [0, 1]
# 4 29 20
# temp: [19, 2] [2, 1]
# 4 29 21
# temp: [20, 2] [4, 1]
# 4 29 22
# temp: [21, 2] [0, 1]
# 4 29 23
# temp: [22, 2] [2, 1]
# 4 29 24
# temp: [23, 2] [4, 1]
# 4 29 25
# temp: [24, 2] [0, 1]
# 4 29 26
# [['Ðồng bằng sông Hồng', 'Hà Nội', 'Hà Tây', 'Vĩnh Phúc'], ['Tổng số', 'Nam'], ['1995']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 1995
# [['Hà Nội', 'Hà Tây', 'Vĩnh Phúc', 'Bắc Ninh'], ['Nam', 'Nữ'], ['1997']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 1997
# [['Hà Tây', 'Vĩnh Phúc', 'Bắc Ninh', 'Quảng Ninh'], ['Nữ', 'Thành thị'], ['1999']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 1999
# [['Vĩnh Phúc', 'Bắc Ninh', 'Quảng Ninh', 'Hải Dương'], ['Thành thị', 'Nông thôn'], ['2001']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2001
# [['Bắc Ninh', 'Quảng Ninh', 'Hải Dương', 'Hải Phòng'], ['Nông thôn'], ['2003']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2003
# [['Quảng Ninh', 'Hải Dương', 'Hải Phòng', 'Hưng Yên'], ['Tổng số', 'Nam'], ['2005']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2005
# [['Hải Dương', 'Hải Phòng', 'Hưng Yên', 'Thái Bình'], ['Nam', 'Nữ'], ['2007']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2007
# [['Hải Phòng', 'Hưng Yên', 'Thái Bình', 'Hà Nam'], ['Nữ', 'Thành thị'], ['2009']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2009
# [['Hưng Yên', 'Thái Bình', 'Hà Nam', 'Nam Ðịnh'], ['Thành thị', 'Nông thôn'], ['2011']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2011
# [['Thái Bình', 'Hà Nam', 'Nam Ðịnh', 'Ninh Bình'], ['Nông thôn'], ['2013']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2013
# [['Hà Nam', 'Nam Ðịnh', 'Ninh Bình', 'Trung du và miền núi phía Bắc'], ['Tổng số', 'Nam'], ['2015']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2015
# [['Nam Ðịnh', 'Ninh Bình', 'Trung du và miền núi phía Bắc', 'Hà Giang'], ['Nam', 'Nữ'], ['2017']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2017
# [['Ninh Bình', 'Trung du và miền núi phía Bắc', 'Hà Giang', 'Cao Bằng'], ['Nữ', 'Thành thị'], ['2019']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2019
# [['Trung du và miền núi phía Bắc', 'Hà Giang', 'Cao Bằng', 'Bắc Kạn'], ['Thành thị', 'Nông thôn'], ['2021']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2021
# [['Hà Giang', 'Cao Bằng', 'Bắc Kạn', 'Tuyên Quang'], ['Nông thôn'], ['Sơ bộ 2023']]
# Dân số Nông thôn trung bình của các địa phương trong năm Sơ bộ 2023
# [['Cao Bằng', 'Bắc Kạn', 'Tuyên Quang', 'Lào Cai'], ['Tổng số', 'Nam'], ['1995']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 1995
# [['Bắc Kạn', 'Tuyên Quang', 'Lào Cai', 'Yên Bái'], ['Nam', 'Nữ'], ['1997']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 1997
# [['Tuyên Quang', 'Lào Cai', 'Yên Bái', 'Thái Nguyên'], ['Nữ', 'Thành thị'], ['1999']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 1999
# [['Lào Cai', 'Yên Bái', 'Thái Nguyên', 'Lạng Sơn'], ['Thành thị', 'Nông thôn'], ['2001']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2001
# [['Yên Bái', 'Thái Nguyên', 'Lạng Sơn', 'Bắc Giang'], ['Nông thôn'], ['2003']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2003
# [['Thái Nguyên', 'Lạng Sơn', 'Bắc Giang', 'Phú Thọ'], ['Tổng số', 'Nam'], ['2005']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2005
# [['Lạng Sơn', 'Bắc Giang', 'Phú Thọ', 'Ðiện Biên'], ['Nam', 'Nữ'], ['2007']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2007
# [['Bắc Giang', 'Phú Thọ', 'Ðiện Biên', 'Lai Châu'], ['Nữ', 'Thành thị'], ['2009']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2009
# [['Phú Thọ', 'Ðiện Biên', 'Lai Châu', 'Sơn La'], ['Thành thị', 'Nông thôn'], ['2011']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2011
# [['Ðiện Biên', 'Lai Châu', 'Sơn La', 'Hoà Bình'], ['Nông thôn'], ['2013']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2013
# [['Lai Châu', 'Sơn La', 'Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung'], ['Tổng số', 'Nam'], ['2015']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2015
# [['Sơn La', 'Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá'], ['Nam', 'Nữ'], ['2017']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2017
# [['Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá', 'Nghệ An'], ['Nữ', 'Thành thị'], ['2019']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2019
# [['Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá', 'Nghệ An', 'Hà Tĩnh'], ['Thành thị', 'Nông thôn'], ['2021']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2021
# [['Thanh Hoá', 'Nghệ An', 'Hà Tĩnh', 'Quảng Bình'], ['Nông thôn'], ['Sơ bộ 2023']]
# Dân số Nông thôn trung bình của các địa phương trong năm Sơ bộ 2023
# [['Nghệ An', 'Hà Tĩnh', 'Quảng Bình', 'Quảng Trị'], ['Tổng số', 'Nam'], ['1995']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 1995
# [['Hà Tĩnh', 'Quảng Bình', 'Quảng Trị', 'Thừa Thiên Huế'], ['Nam', 'Nữ'], ['1997']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 1997
# [['Quảng Bình', 'Quảng Trị', 'Thừa Thiên Huế', 'Ðà Nẵng'], ['Nữ', 'Thành thị'], ['1999']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 1999
# [['Quảng Trị', 'Thừa Thiên Huế', 'Ðà Nẵng', 'Quảng Nam'], ['Thành thị', 'Nông thôn'], ['2001']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2001
# [['Thừa Thiên Huế', 'Ðà Nẵng', 'Quảng Nam', 'Quảng Ngãi'], ['Nông thôn'], ['2003']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2003
# [['Ðà Nẵng', 'Quảng Nam', 'Quảng Ngãi', 'Bình Ðịnh'], ['Tổng số', 'Nam'], ['2005']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2005
# [['Quảng Nam', 'Quảng Ngãi', 'Bình Ðịnh', 'Phú Yên'], ['Nam', 'Nữ'], ['2007']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2007
# [['Quảng Ngãi', 'Bình Ðịnh', 'Phú Yên', 'Khánh Hoà'], ['Nữ', 'Thành thị'], ['2009']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2009
# [['Bình Ðịnh', 'Phú Yên', 'Khánh Hoà', 'Ninh Thuận'], ['Thành thị', 'Nông thôn'], ['2011']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2011
# [['Phú Yên', 'Khánh Hoà', 'Ninh Thuận', 'Bình Thuận'], ['Nông thôn'], ['2013']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2013
# [['Khánh Hoà', 'Ninh Thuận', 'Bình Thuận', 'Tây Nguyên'], ['Tổng số', 'Nam'], ['2015']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2015
# [['Ninh Thuận', 'Bình Thuận', 'Tây Nguyên', 'Kon Tum'], ['Nam', 'Nữ'], ['2017']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2017
# [['Bình Thuận', 'Tây Nguyên', 'Kon Tum', 'Gia Lai'], ['Nữ', 'Thành thị'], ['2019']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2019
# [['Tây Nguyên', 'Kon Tum', 'Gia Lai', 'Ðắk Lắk'], ['Thành thị', 'Nông thôn'], ['2021']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2021
# [['Kon Tum', 'Gia Lai', 'Ðắk Lắk', 'Ðắk Nông'], ['Nông thôn'], ['Sơ bộ 2023']]
# Dân số Nông thôn trung bình của các địa phương trong năm Sơ bộ 2023
# [['Gia Lai', 'Ðắk Lắk', 'Ðắk Nông', 'Lâm Ðồng'], ['Tổng số', 'Nam'], ['1995']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 1995
# [['Ðắk Lắk', 'Ðắk Nông', 'Lâm Ðồng', 'Ðông Nam Bộ'], ['Nam', 'Nữ'], ['1997']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 1997
# [['Ðắk Nông', 'Lâm Ðồng', 'Ðông Nam Bộ', 'Bình Phước'], ['Nữ', 'Thành thị'], ['1999']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 1999
# [['Lâm Ðồng', 'Ðông Nam Bộ', 'Bình Phước', 'Tây Ninh'], ['Thành thị', 'Nông thôn'], ['2001']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2001
# [['Ðông Nam Bộ', 'Bình Phước', 'Tây Ninh', 'Bình Dương'], ['Nông thôn'], ['2003']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2003
# [['Bình Phước', 'Tây Ninh', 'Bình Dương', 'Ðồng Nai'], ['Tổng số', 'Nam'], ['2005']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2005
# [['Tây Ninh', 'Bình Dương', 'Ðồng Nai', 'Bà Rịa - Vũng Tàu'], ['Nam', 'Nữ'], ['2007']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2007
# [['Bình Dương', 'Ðồng Nai', 'Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh'], ['Nữ', 'Thành thị'], ['2009']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2009
# [['Ðồng Nai', 'Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh', 'Ðồng bằng sông Cửu Long'], ['Thành thị', 'Nông thôn'], ['2011']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2011
# [['Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh', 'Ðồng bằng sông Cửu Long', 'Long An'], ['Nông thôn'], ['2013']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2013
# [['TP.Hồ Chí Minh', 'Ðồng bằng sông Cửu Long', 'Long An', 'Tiền Giang'], ['Tổng số', 'Nam'], ['2015']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2015
# [['Ðồng bằng sông Cửu Long', 'Long An', 'Tiền Giang', 'Bến Tre'], ['Nam', 'Nữ'], ['2017']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2017
# [['Long An', 'Tiền Giang', 'Bến Tre', 'Trà Vinh'], ['Nữ', 'Thành thị'], ['2019']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 2019
# [['Tiền Giang', 'Bến Tre', 'Trà Vinh', 'Vĩnh Long'], ['Thành thị', 'Nông thôn'], ['2021']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2021
# [['Bến Tre', 'Trà Vinh', 'Vĩnh Long', 'Ðồng Tháp'], ['Nông thôn'], ['Sơ bộ 2023']]
# Dân số Nông thôn trung bình của các địa phương trong năm Sơ bộ 2023
# [['Trà Vinh', 'Vĩnh Long', 'Ðồng Tháp', 'An Giang'], ['Tổng số', 'Nam'], ['1995']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 1995
# [['Vĩnh Long', 'Ðồng Tháp', 'An Giang', 'Kiên Giang'], ['Nam', 'Nữ'], ['1997']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 1997
# [['Ðồng Tháp', 'An Giang', 'Kiên Giang', 'Cần Thơ'], ['Nữ', 'Thành thị'], ['1999']]
# Dân số Nữ, Thành thị trung bình của các địa phương trong năm 1999
# [['An Giang', 'Kiên Giang', 'Cần Thơ', 'Hậu Giang'], ['Thành thị', 'Nông thôn'], ['2001']]
# Dân số Thành thị, Nông thôn trung bình của các địa phương trong năm 2001
# [['Kiên Giang', 'Cần Thơ', 'Hậu Giang', 'Sóc Trăng'], ['Nông thôn'], ['2003']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2003
# [['Cần Thơ', 'Hậu Giang', 'Sóc Trăng', 'Bạc Liêu'], ['Tổng số', 'Nam'], ['2005']]
# Dân số Tổng số, Nam trung bình của các địa phương trong năm 2005
# [['Hậu Giang', 'Sóc Trăng', 'Bạc Liêu', 'Cà Mau'], ['Nam', 'Nữ'], ['2007']]
# Dân số Nam, Nữ trung bình của các địa phương trong năm 2007
# [['CẢ NƯỚC', 'Ðồng bằng sông Hồng'], ['Nam', 'Nữ', 'Thành thị', 'Nông thôn'], ['1995']]
# Dân số trung bình giới tính và thành thị nông thôn của CẢ NƯỚC, Ðồng bằng sông Hồng trong năm 1995
# [['CẢ NƯỚC', 'Ðồng bằng sông Hồng'], ['Tổng số'], ['1996', '1997', '1998', '1999']]
# Dân số Tổng số trung bình của các địa phương trong năm 1996, 1997, 1998, 1999
# [['Ðồng bằng sông Hồng', 'Hà Nội'], ['Nữ'], ['1997', '1998', '1999', '2000']]
# Dân số Nữ trung bình của các địa phương trong năm 1997, 1998, 1999, 2000
# [['Hà Nội', 'Hà Tây'], ['Nông thôn'], ['1998', '1999', '2000', '2001']]
# Dân số trung bình Nông thôn của Hà Nội, Hà Tây qua các năm
# [['Hà Tây', 'Vĩnh Phúc'], ['Tổng số'], ['1999', '2000', '2001', '2002']]
# Dân số trung bình Tổng số của Hà Tây, Vĩnh Phúc qua các năm
# [['Vĩnh Phúc', 'Bắc Ninh'], ['Nữ'], ['2000', '2001', '2002', '2003']]
# Dân số trung bình Nữ của Vĩnh Phúc, Bắc Ninh qua các năm
# [['Bắc Ninh', 'Quảng Ninh'], ['Nông thôn'], ['2001', '2002', '2003', '2004']]
# Dân số trung bình Nông thôn của Bắc Ninh, Quảng Ninh qua các năm
# [['Quảng Ninh', 'Hải Dương'], ['Tổng số'], ['2002', '2003', '2004', '2005']]
# Dân số trung bình Tổng số của Quảng Ninh, Hải Dương qua các năm
# [['Hải Dương', 'Hải Phòng'], ['Nữ'], ['2003', '2004', '2005', '2006']]
# Dân số trung bình Nữ của Hải Dương, Hải Phòng qua các năm
# [['Hải Phòng', 'Hưng Yên'], ['Nông thôn'], ['2004', '2005', '2006', '2007']]
# Dân số trung bình Nông thôn của Hải Phòng, Hưng Yên qua các năm
# [['Hưng Yên', 'Thái Bình'], ['Tổng số'], ['2005', '2006', '2007', '2008']]
# Dân số trung bình Tổng số của Hưng Yên, Thái Bình qua các năm
# [['Thái Bình', 'Hà Nam'], ['Nữ'], ['2006', '2007', '2008', '2009']]
# Dân số trung bình Nữ của Thái Bình, Hà Nam qua các năm
# [['Hà Nam', 'Nam Ðịnh'], ['Nông thôn'], ['2007', '2008', '2009', '2010']]
# Dân số trung bình Nông thôn của Hà Nam, Nam Ðịnh qua các năm
# [['Nam Ðịnh', 'Ninh Bình'], ['Tổng số'], ['2008', '2009', '2010', '2011']]
# Dân số trung bình Tổng số của Nam Ðịnh, Ninh Bình qua các năm
# [['Ninh Bình', 'Trung du và miền núi phía Bắc'], ['Nữ'], ['2009', '2010', '2011', '2012']]
# Dân số Nữ trung bình của các địa phương trong năm 2009, 2010, 2011, 2012
# [['Trung du và miền núi phía Bắc', 'Hà Giang'], ['Nông thôn'], ['2010', '2011', '2012', '2013']]
# Dân số Nông thôn trung bình của các địa phương trong năm 2010, 2011, 2012, 2013
# [['Hà Giang', 'Cao Bằng'], ['Tổng số'], ['2011', '2012', '2013', '2014']]
# Dân số trung bình Tổng số của Hà Giang, Cao Bằng qua các năm
# [['Cao Bằng', 'Bắc Kạn'], ['Nữ'], ['2012', '2013', '2014', '2015']]
# Dân số trung bình Nữ của Cao Bằng, Bắc Kạn qua các năm
# [['Bắc Kạn', 'Tuyên Quang'], ['Nông thôn'], ['2013', '2014', '2015', '2016']]
# Dân số trung bình Nông thôn của Bắc Kạn, Tuyên Quang qua các năm
# [['Tuyên Quang', 'Lào Cai'], ['Tổng số'], ['2014', '2015', '2016', '2017']]
# Dân số trung bình Tổng số của Tuyên Quang, Lào Cai qua các năm
# [['Lào Cai', 'Yên Bái'], ['Nữ'], ['2015', '2016', '2017', '2018']]
# Dân số trung bình Nữ của Lào Cai, Yên Bái qua các năm
# [['Yên Bái', 'Thái Nguyên'], ['Nông thôn'], ['2016', '2017', '2018', '2019']]
# Dân số trung bình Nông thôn của Yên Bái, Thái Nguyên qua các năm
# [['Thái Nguyên', 'Lạng Sơn'], ['Tổng số'], ['2017', '2018', '2019', '2020']]
# Dân số trung bình Tổng số của Thái Nguyên, Lạng Sơn qua các năm
# [['Lạng Sơn', 'Bắc Giang'], ['Nữ'], ['2018', '2019', '2020', '2021']]
# Dân số trung bình Nữ của Lạng Sơn, Bắc Giang qua các năm
# [['Bắc Giang', 'Phú Thọ'], ['Nông thôn'], ['2019', '2020', '2021', '2022']]
# Dân số trung bình Nông thôn của Bắc Giang, Phú Thọ qua các năm
# [['Phú Thọ', 'Ðiện Biên'], ['Tổng số'], ['2020', '2021', '2022', 'Sơ bộ 2023']]
# Dân số trung bình Tổng số của Phú Thọ, Ðiện Biên qua các năm
